# %%
import json
import os

# %%
path = "./tests/new_tweets/"

# %%
print(os.listdir(path))
# Out:
# ['1430039883716911107.json', '1430039885499576333.json', '1430039886611066898.json', '1430039895641403420.json', '1430039898690662431.json', '1430039901408571404.json', '1430039901861384197.json', '1430039907746164743.json', '1430039910271143938.json', '1430039916726169602.json', '1430039918139482112.json', '1430039918605217798.json', '1430039919179837446.json', '1430039920043696135.json', '1430039924984750081.json', '1430039928193183748.json', '1430039931951353860.json', '1430039933436141571.json', '1430039934618849281.json', '1430039934644236314.json', '1430039934690217988.json', '1430039936837713920.json', '1430039936921608193.json', '1430039937177591808.json', '1430039938540523522.json', '1430039940587397125.json', '1430039941103464457.json', '1430039942973952006.json', '1430039943360000000.json', '1430039944236503040.json', '1430039946451202067.json', '1430039948552454144.json', '1430039948770484224.json', '1430039949500354560.json', '1430039949592735779.json', '1430039951220125
# ...

# %%
json.load(open(path+"1430039919179837446.json", "r"))
# Out:
# {'created_at': 'Tue Aug 24 05:31:00 +0000 2021',
#  'id': 1430039919179837446,
#  'id_str': '1430039919179837446',
#  'full_text': ".@GovAbbott @teainfo “Please reverse the mandate our kids will be at risk. W/out the virtual learning option this is very scary being forced to send our younger children back to school, they're not old enough to take the vaccine.” -Parent in Cypress #txlege #KeepTXKidsCOVIDFree",
#  'truncated': False,
#  'display_text_range': [0, 278],
#  'entities': {'hashtags': [{'text': 'txlege', 'indices': [250, 257]},
#    {'text': 'KeepTXKidsCOVIDFree', 'indices': [258, 278]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'GovAbbott',
#     'name': 'Gov. Greg Abbott',
#     'id': 19291441,
#     'id_str': '19291441',
#     'indices': [1, 11]},
#    {'screen_name': 'teainfo',
#     'name': 'Texas Education Agency',
#     'id': 22182297,
#     'id_str': '22182297',
#     'indices': [12, 20]}],
#   'urls': []},
# ...
