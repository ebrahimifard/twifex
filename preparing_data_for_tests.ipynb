# %%
import pickle as pk
import pandas as pd

# %%
data = pk.load(open("v2.0/all_conditions.pk", "rb"))

# %%
df = pd.DataFrame.from_dict(data).T.reset_index().rename(columns={"index":"tweet_path"})

# %%
df.append(df.sum(), ignore_index=True)
# Out:
# C:\Users\P70076~1\AppData\Local\Temp/ipykernel_27916/3602671177.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.append(df.sum(), ignore_index=True)
#                                          tweet_path    c_rt    c_qt  c_fig  \
# 0      ..\tests\new_tweets\1430024304129986564.json   False   False  False
# 1                     ..\tests\test_case\20744.json    True   False  False
# 2            ..\tests\test_case_original\13162.json    True   False  False
# 3           ..\tests\test_case_original\398621.json    True   False  False
# 4           ..\tests\test_case_original\341878.json   False   False  False
# ...                                             ...     ...     ...    ...
# 14224  ..\tests\new_tweets\1430025347953790980.json   False   False  False
# ...

# %%
l = list(df.loc[(df["c_rt"] == True) & (df["c_qt"] == True)]["tweet_path"])

# %%
d = set()
for i in l:
    d.add(i.parts[2])
    if i.parts[2] == "data":
        print(i)
# Out:
# ..\tests\data\196873.json
# ..\tests\data\quote.json
# ..\tests\data\196852.json

# %%
d
# Out:
# {'data', 'test_case', 'test_case_original'}
